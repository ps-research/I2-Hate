# %%
# !pip install bertopic umap-learn hdbscan sentence-transformers plotly --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 7.2 MB/s eta 0:00:00

# %%
import json
import pandas as pd
import numpy as np
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from hdbscan import HDBSCAN
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.12/dist-packages/hdbscan/robust_single_linkage_.py:175: SyntaxWarning: invalid escape sequence '\{'
#   $max \{ core_k(a), core_k(b), 1/\alpha d(a,b) \}$.

# %%
with open('/content/drive/MyDrive/EACL NEW DATA/EACL_26-HateSpeechDataset.json', 'r') as f:
    data = json.load(f)

texts = [sample['text'] for sample in data]
print(f"Loaded {len(texts)} tweets\n")
# Out:
# Loaded 3296 tweets

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

nltk_stopwords = list(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
vectorizer_model = CountVectorizer(
    stop_words=nltk_stopwords,
    min_df=2,           # Ignore very rare words
    max_df=0.95,        # Ignore very common words
    ngram_range=(1, 3)  # Allow phrases (unigrams to trigrams)
)

# %%
embedding_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
umap_model = UMAP(
    n_neighbors=15,
    n_components=5,
    min_dist=0.0,
    metric='cosine',
    random_state=42
)

# %%
hdbscan_model = HDBSCAN(
    min_cluster_size=30,
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True
)

# %%
keybert_model = KeyBERTInspired()
mmr_model = MaximalMarginalRelevance(diversity=0.3)
representation_model = {
    "KeyBERT": keybert_model,
    "MMR": mmr_model
}

# %%
topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    top_n_words=10,
    nr_topics="auto",
    verbose=True
)

# %%
topics, probs = topic_model.fit_transform(texts)
# Out:
# 2025-11-23 14:21:02,335 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/103 [00:00<?, ?it/s]
# 2025-11-23 14:21:14,591 - BERTopic - Embedding - Completed ✓
# 2025-11-23 14:21:14,594 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-23 14:21:44,683 - BERTopic - Dimensionality - Completed ✓
# 2025-11-23 14:21:44,684 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-23 14:21:44,786 - BERTopic - Cluster - Completed ✓
# 2025-11-23 14:21:44,787 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-11-23 14:21:45,739 - BERTopic - Representation - Completed ✓
# 2025-11-23 14:21:45,741 - BERTopic - Topic reduction - Reducing number of topics
# 2025-11-23 14:21:45,750 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-23 14:21:48,255 - BERTopic - Representation - Completed ✓
# 2025-11-23 14:21:48,257 - BERTopic - Topic reduction - Reduced number of topics from 26 to 22

# %%
topic_info = topic_model.get_topic_info()
print(f"Found {len(topic_info) - 1} topics (excluding outliers)")
# Out:
# Found 21 topics (excluding outliers)

# %%
# Show topics with better keywords
for topic_id in range(min(15, len(topic_info)-1)):
    if topic_id == -1:
        continue

    print(f"\nTOPIC {topic_id} ({topic_info[topic_info['Topic']==topic_id]['Count'].values[0]} posts)")
    print("-" * 80)

    # Get keywords from different representations
    topic_words = topic_model.get_topic(topic_id)

    print("Top keywords (KeyBERT):")
    if hasattr(topic_model, 'get_topic_representations'):
        keybert_words = topic_model.topic_representations_[topic_id]['KeyBERT'][:10]
        print(", ".join([word for word, _ in keybert_words]))
    else:
        print(", ".join([word for word, _ in topic_words[:10]]))

    print("\nTop keywords (MMR):")
    if hasattr(topic_model, 'get_topic_representations'):
        mmr_words = topic_model.topic_representations_[topic_id]['MMR'][:10]
        print(", ".join([word for word, _ in mmr_words]))

    # Show representative documents
    docs = topic_model.get_representative_docs(topic_id)[:2]
    print("\nRepresentative posts:")
    for i, doc in enumerate(docs, 1):
        print(f"  {i}. {doc[:150]}...")
# Out:
# TOPIC 0 (752 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# soros, george, black, george soros, country, border, blm, lives, funded, antifa
#
# Top keywords (MMR):
#
# Representative posts:
#   1. The parallels are undeniable for anyone who has read a history book. In 1917, Leon Trotsky and his Bolsheviks were funded by New York bankers like Jac...
#   2. The historical parallel is a straight line, not a curve. In 1917, the anti-Christian Bolshevik Revolution was bankrolled by Wall Street financiers lik...
#
# TOPIC 1 (579 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# aipac, cia, foreign, israel, mossad, american, fbi, military, treason, patriots
#
# Top keywords (MMR):
#
# Representative posts:
#   1. It must be understood that AIPAC is not an American organization. It is the political arm of a foreign tribe, a fifth column operating with impunity w...
#   2. America is a nation under occupation. The capitol is not Washington D.C., but Tel Aviv. Our government is a Zionist Occupation Government (ZOG), and i...
#
# TOPIC 2 (164 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# 1b, american, tech, class, workers, visa, asian, china, model, india
#
# Top keywords (MMR):
#
# Representative posts:
#   1. The H-1B visa is not an immigration program; it is a declaration of war on the American middle class. We are a nation, not a marketplace. Our first an...
#   2. The entire 'STEM shortage' narrative is a carefully constructed lie. We have plenty of American engineers. What we have is a coordinated effort by the...
#
# TOPIC 3 (106 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# kgb, putin, fsb, russian, kremlin, regime, west, nato, russia, moscow
#
# Top keywords (MMR):
#
# Representative posts:
#   1. Let's be crystal clear: the KGB was not 'disbanded' in 1991. It performed a corporate rebranding and became the FSB. The institution, the personnel, a...
#   2. The problem isn't just Putin; it's the entire culture that the KGB/FSB has cultivated for a century. Russian culture as it is promoted abroad—the Bols...
#
# TOPIC 4 (98 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# land, reservation, tribal, tribes, reservations, going, culture, alcoholism, indigenous, water
#
# Top keywords (MMR):
#
# Representative posts:
#   1. Let's be brutally honest about the state of reservations like the Rosebud Sioux Tribe in South Dakota. It is a failed state. It is a human wasteland o...
#   2. The poverty on the Pine Ridge Reservation is not America's failure; it is the Oglala Lakota's failure. It is a perfect case study of what happens when...
#
# TOPIC 5 (97 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# maga, trump, fascist, movement, supporters, democracy, trump supporters, fascists, fascism, red
#
# Top keywords (MMR):
#
# Representative posts:
#   1. Fascism is not an opinion; it's a threat that must be physically destroyed. History has taught us that you cannot vote it away. We must look to the re...
#   2. It's time we stop pretending that Trump supporters are just people with a different political opinion. They are not. They are members of a fascist dea...
#
# TOPIC 6 (96 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# hollywood, disney, white, culture, zaslav, iger, anti, tribe, warner, control
#
# Top keywords (MMR):
#
# Representative posts:
#   1. THREAD 1/4: People say it's a 'conspiracy theory,' but the facts are publicly available if you know where to look. Let's examine the leadership at the...
#   2. Let’s be very clear about what is happening. This is not a random 'culture war.' It is a coordinated psychological operation being executed from the t...
#
# TOPIC 7 (96 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# confederate, confederacy, south, slavery, lee, flag, federal, general, fought, defending
#
# Top keywords (MMR):
#
# Representative posts:
#   1. The cause of the Confederacy was, and remains, a righteous one. It was the cause of limited government, of cultural integrity, and of a people's right...
#   2. The cause for which the Confederate soldier fought was the cause of constitutional liberty and the right of self-government. They stood against the co...
#
# TOPIC 8 (89 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# syndicate, nostra, kosher, kosher nostra, judge, judges, legal, justice, tribe, lawyers
#
# Top keywords (MMR):
#
# Representative posts:
#   1. A brief thread on the modern 'Kosher Nostra.'
# 1/5 People mistakenly believe organized crime faded after the RICO Act. In reality, it just changed mana...
#   2. A fascinating case study in how the Kosher Nostra operates its legal firewall is the law firm Skadden, Arps. You have a constant flow of their top par...
#
# TOPIC 9 (86 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# rothschild, federal reserve, reserve, federal, fed, banking, rothschilds, debt, bank, financial
#
# Top keywords (MMR):
#
# Representative posts:
#   1. It's vital that patriots understand the foundational act of treason that led to our current predicament. On a foggy November night in 1910, a group of...
#   2. 1/4 Let's talk about the Federal Reserve. It’s not Federal, and it has no reserves. It is a private banking cartel, established in 1913 by Illuminati-...
#
# TOPIC 10 (83 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# germany, german, hitler, reich, leader, third reich, understood, weimar, 1933, third
#
# Top keywords (MMR):
#
# Representative posts:
#   1. The remilitarization of the Rhineland in March 1936 was one of the most masterful geopolitical moves of the 20th century. The Versailles Treaty had un...
#   2. 1/ Let's have an honest discussion about the outbreak of war in 1939, something the court historians refuse to do. The standard narrative is that Germ...
#
# TOPIC 11 (83 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# holohoax, lie, story, holocaust, historical, chambers, jewish, hitler, million, narrative
#
# Top keywords (MMR):
#
# Representative posts:
#   1. The Holohoax is the foundational myth of the modern parasite. Without it, they would have no moral justification for their behavior. Think of George S...
#   2. One of the most damning pieces of evidence against the Holohoax is simple demographics. The 1940 World Almanac, published by the American Jewish Commi...
#
# TOPIC 12 (81 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# food, gates, bill gates, bill, slop, goy slop, goy, eat, lab, grown
#
# Top keywords (MMR):
#
# Representative posts:
#   1. It’s not complicated, people. Just connect the dots. 1) Bill Gates becomes the largest private owner of farmland in America. 2) Mysterious fires start...
#   2. It's not a conspiracy, it's a documented agenda. Follow the sequence. 1) Bill Gates quietly becomes the largest private owner of farmland in the USA. ...
#
# TOPIC 13 (79 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# wef, schwab, klaus, klaus schwab, greatreset, reset, great reset, social credit, credit, davos
#
# Top keywords (MMR):
#
# Representative posts:
#   1. It's not a conspiracy theory when they tell you the plan. Klaus Schwab's book, 'COVID-19: The Great Reset,' is their Mein Kampf. He explicitly states ...
#   2. Oh my god, I am so excited for the Great Reset! I just read on the World Economic Forum's website that I will own nothing and be happy, and I can't wa...
#
# TOPIC 14 (78 posts)
# --------------------------------------------------------------------------------
# Top keywords (KeyBERT):
# woman, creature, utterly, perfect, empowerment, walking, voice, country, thinks, frankfurt
#
# Top keywords (MMR):
#
# Representative posts:
#   1. Observe the modern feminist, the final product of the Frankfurt School's grand experiment. A creature of deep pity. She traded the sacred throne of th...
#   2. I just saw a magazine cover celebrating a 40-year-old, childless female CEO as a 'woman who has it all.' It filled me with a cold rage. She has NOTHIN...

# %%
def generate_topic_label(topic_id):
    """Generate descriptive label from top keywords"""
    if topic_id == -1:
        return "Outliers"

    topic_words = topic_model.get_topic(topic_id)

    # Get top 3 most representative words
    top_words = [word for word, _ in topic_words[:3]]

    # Create label
    label = " + ".join(top_words).title()
    return label

# Apply automatic labels
topic_info['Auto_Label'] = topic_info['Topic'].apply(generate_topic_label)

# %%
def infer_category(keywords):
    keywords_lower = " ".join([w.lower() for w, _ in keywords])

    # Immigration
    if any(word in keywords_lower for word in ['immig', 'border', 'illegal', 'deport', 'alien', 'refugee', 'asylum']):
        return "Immigration"

    # Religion (including coded antisemitism)
    elif any(word in keywords_lower for word in [
        'jew', 'jewish', 'israel', 'zionist', 'antisem', 'muslim', 'islam', 'christian', 'religion',
        'soros', 'rothschild', 'aipac', 'mossad', 'zog', 'holohoax', 'holocaust',  # ADDED
        'synagogue', 'mosque', 'kosher', 'sharia', 'jihad'  # ADDED
    ]):
        return "Religion"

    # Race & Ethnicity
    elif any(word in keywords_lower for word in [
        'black', 'white', 'race', 'racial', 'blm', 'african', 'asian', 'chinese',
        'confederate', 'slavery', 'slave', 'kkk', 'supremac'  # ADDED
    ]):
        return "Race & Ethnicity"

    # LGBTQ+ & Gender
    elif any(word in keywords_lower for word in ['trans', 'gay', 'lgbt', 'queer', 'gender', 'pronoun', 'homosexual']):
        return "LGBTQ+ & Gender"

    # Women & Gender
    elif any(word in keywords_lower for word in ['women', 'woman', 'feminist', 'female', 'misog', 'bitch', 'slut', 'whore']):
        return "Women & Gender"

    # Politics (NEW CATEGORY)
    elif any(word in keywords_lower for word in [
        'trump', 'maga', 'democrat', 'republican', 'liberal', 'conserv', 'election', 'vote',
        'biden', 'obama', 'clinton', 'fascist', 'communist', 'socialist'
    ]):
        return "Politics"

    # Conspiracy Theories (NEW CATEGORY)
    elif any(word in keywords_lower for word in [
        'gates', 'bill gates', 'deep state', 'cabal', 'elite', 'globalist',
        'federal reserve', 'fed', 'illuminati', 'mason', 'satanic', 'pedophile'
    ]):
        return "Conspiracy Theories"

    # Health/COVID (if relevant)
    elif any(word in keywords_lower for word in ['vacc', 'covid', 'virus', 'pandemic', 'mask']):
        return "Health & COVID"

    # Native/Indigenous Issues (NEW)
    elif any(word in keywords_lower for word in ['tribal', 'reservation', 'native', 'indigenous', 'aboriginal']):
        return "Indigenous Issues"

    else:
        return "Other"

topic_info['Category'] = topic_info['Topic'].apply(
    lambda t: infer_category(topic_model.get_topic(t)) if t != -1 else "Outliers"
)

# %%
topics_df = topic_info[topic_info['Topic'] != -1].copy()
topics_df['Percentage'] = (topics_df['Count'] / len(texts) * 100).round(1)
topics_df = topics_df.sort_values('Count', ascending=False)

# %%
print("TOPIC SUMMARY (Top 15)")
print(topics_df[['Topic', 'Category', 'Auto_Label', 'Count', 'Percentage']].head(15).to_string(index=False))
# Out:
# TOPIC SUMMARY (Top 15)
#  Topic            Category                             Auto_Label  Count  Percentage
#      0         Immigration                 Soros + George + Black    752        22.8
#      1            Religion                  Aipac + Cia + Foreign    579        17.6
#      2    Race & Ethnicity                   1B + American + Tech    164         5.0
#      3               Other                      Kgb + Putin + Fsb    106         3.2
#      4   Indigenous Issues            Land + Reservation + Tribal     98         3.0
#      5            Politics                 Maga + Trump + Fascist     97         2.9
#      6    Race & Ethnicity             Hollywood + Disney + White     96         2.9
#      7    Race & Ethnicity      Confederate + Confederacy + South     96         2.9
#      8            Religion            Syndicate + Nostra + Kosher     89         2.7
#      9            Religion Rothschild + Federal Reserve + Reserve     86         2.6
#     10               Other              Germany + German + Hitler     83         2.5
#     11            Religion                 Holohoax + Lie + Story     83         2.5
#     12 Conspiracy Theories              Food + Gates + Bill Gates     81         2.5
#     13               Other                   Wef + Schwab + Klaus     79         2.4
#     14      Women & Gender             Woman + Creature + Utterly     78         2.4

# %%
category_counts = topics_df.groupby('Category').agg({
    'Count': 'sum',
    'Topic': 'count'
}).rename(columns={'Topic': 'Num_Topics'})
category_counts['Percentage'] = (category_counts['Count'] / len(texts) * 100).round(1)
category_counts = category_counts.sort_values('Count', ascending=False)

# %%
print("SOCIAL ISSUE CATEGORIES")
print(category_counts.to_string())
# Out:
# SOCIAL ISSUE CATEGORIES
#                      Count  Num_Topics  Percentage
# Category
# Religion               837           4        25.4
# Immigration            752           1        22.8
# Race & Ethnicity       356           3        10.8
# Other                  316           4         9.6
# Conspiracy Theories    225           3         6.8
# Women & Gender         208           3         6.3
# Indigenous Issues       98           1         3.0
# Politics                97           1         2.9
# LGBTQ+ & Gender         45           1         1.4

# %%
fig, ax = plt.subplots(figsize=(10, 6))
categories = category_counts.index.tolist()
counts = category_counts['Count'].tolist()
percentages = category_counts['Percentage'].tolist()

colors = plt.cm.Set3(range(len(categories)))
bars = ax.barh(categories, counts, color=colors)

ax.set_xlabel('Number of Posts', fontsize=12, fontweight='bold')
ax.set_ylabel('Social Issue Category', fontsize=12, fontweight='bold')
ax.set_title('Distribution of Social Issues in I2-HATE Dataset\n(BERTopic Automatic Classification)',
             fontsize=14, fontweight='bold')
ax.invert_yaxis()

# Add percentage labels
for i, (cat, count, pct) in enumerate(zip(categories, counts, percentages)):
    ax.text(count + 20, i, f'{pct:.1f}%', va='center', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
top15 = topics_df.head(15).copy()
labels = top15['Auto_Label'].tolist()
counts = top15['Count'].tolist()

# Color by category
category_colors = {cat: plt.cm.Set3(i) for i, cat in enumerate(category_counts.index)}
colors = [category_colors[cat] for cat in top15['Category']]

bars = ax.barh(range(len(labels)), counts, color=colors)
ax.set_yticks(range(len(labels)))
ax.set_yticklabels(labels, fontsize=10)
ax.set_xlabel('Number of Posts', fontsize=12, fontweight='bold')
ax.set_title('Top 15 Topics in I2-HATE Dataset',
             fontsize=14, fontweight='bold')
ax.invert_yaxis()

# Add counts
for i, count in enumerate(counts):
    ax.text(count + 10, i, str(count), va='center', fontsize=9)

plt.tight_layout()
plt.show()
